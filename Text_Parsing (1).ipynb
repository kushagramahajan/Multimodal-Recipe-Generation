# %%
import json
  
# Opening JSON file
layer1 = open('/content/drive/MyDrive/11777/layer1.json')
layer2 = open('/content/drive/MyDrive/11777/layer2.json')
layer1_j=json.load(layer1)
# layer2_j=json.load(layer2)

# %%
len(layer1_j)
# Out:
# 1029720

# %%
len(layer2_j)
# Out:
# 402760

# %%
layer1_j[0]
# Out:
# {'ingredients': [{'text': '6 ounces penne'},
#   {'text': '2 cups Beechers Flagship Cheese Sauce (recipe follows)'},
#   {'text': '1 ounce Cheddar, grated (1/4 cup)'},
#   {'text': '1 ounce Gruyere cheese, grated (1/4 cup)'},
#   {'text': '1/4 to 1/2 teaspoon chipotle chili powder (see Note)'},
#   {'text': '1/4 cup (1/2 stick) unsalted butter'},
#   {'text': '1/3 cup all-purpose flour'},
#   {'text': '3 cups milk'},
#   {'text': '14 ounces semihard cheese (page 23), grated (about 3 1/2 cups)'},
#   {'text': '2 ounces semisoft cheese (page 23), grated (1/2 cup)'},
#   {'text': '1/2 teaspoon kosher salt'},
#   {'text': '1/4 to 1/2 teaspoon chipotle chili powder'},
#   {'text': '1/8 teaspoon garlic powder'},
#   {'text': '(makes about 4 cups)'}],
#  'url': 'http://www.epicurious.com/recipes/food/views/-world-s-best-mac-and-cheese-387747',
#  'partition': 'train',
#  'title': 'Worlds Best Mac and Cheese',
#  'id': '000018c8a5',
# ...

# %%
layer2_j[0]['images'][0]['id']
# Out:
# '3e233001e2.jpg'

# %%
layer2_j[0]['id']
# Out:
# '00003a70b1'

# %%
layer1_j[0]['id']
# Out:
# '000018c8a5'

# %%
ids[0]
# Out:
# '00029f71f7'

# %%
if("f63acd3406" in ids):
    print("yes")
# Out:
# yes

# %%
for i in layer1['text']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-1efba232ed6f> in <module>
# ----> 1 for i in layer1['text']:
#       2     print(i)
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
with open('val_names.txt', 'w') as fp:
    for item in a:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
names=[]
with open('val_names.txt', 'r') as fp:
    for line in fp:
        x = line[:-1]
        names.append(x)

# %%
len(names)
# Out:
# 133842

# %%
count=0
ids=[]
for i in range (0, len(layer2_j)):
    for j in range (0,len(layer2_j[i]['images'])):
        if((layer2_j[i]['images'][j]['id'] in names) and count<133843):
            ids.append(layer2_j[i]['id'])
            count=count+1
            print(count)

# %%
with open('val_ids.txt', 'w') as fp:
    for item in ids:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
ids=set()
with open('val_ids.txt', 'r') as fp:
    for line in fp:
        x = line[:-1]
        ids.add(x)

# %%
ids=[]
with open('val_ids.txt', 'r') as fp:
    for line in fp:
        x = line[:-1]
        ids.append(x)

# %%
ids[0:10]
# Out:
# ['00029f71f7',
#  '00029f71f7',
#  '0004c091a0',
#  '000507ca6b',
#  '0006354bc3',
#  '0006354bc3',
#  '00081bb5ef',
#  '000875a149',
#  '000875a149',
#  '00089c3010']

# %%
len(ids)
# Out:
# 133842

# %%
count=0
recipes=[]
unique_id=[]
id_rec={}
for i in range (0, len(layer1_j)):
    if((layer1_j[i]['id'] in ids) and count<133843):
        count=count+1
        # print(count)
        unique_id.append(layer1_j[i]['id'])
        dummy=[]
        for j in range(0,len(layer1_j[i]['instructions'])):
            dummy.append(layer1_j[i]['instructions'][j]['text'])
        recipes.append(dummy)
        id_rec[layer1_j[i]['id']]=dummy

# %%
with open('unique_val_ids.txt', 'w') as fp:
    for item in unique_id:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
with open('unique_val_recipes.txt', 'w') as fp:
    for item in recipes:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
print(recipes[0])
# Out:
# ['14 cup butter', '34 cup brown sugar', '1 egg', '13 cup orange juice concentrate', '1 tablespoon grated orange rind', '2 cups flour', '1 teaspoon baking soda', '12 teaspoon salt', '1 cup crushed pineapple with juice', '12 cup chopped pecans (optional)']

# %%
with open("id_rec_map.json", "w") as outfile:
    json.dump(id_rec, outfile)

# %%
final_recipes=[]
for i in range(0,len(ids)):
    try:
        final_recipes.append(id_rec[ids[i]])
    except:
        print(ids[i])

# %%
with open('val_recipes_final.txt', 'w') as fp:
    for item in final_recipes:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
article=nlp("Cook the penne 2 minutes less than package directions")

# %%
for X in article.ents:
    print("Text:",X.text,"\tLabel:",X.label_)
# Out:
# Text: 2 minutes 	Label: TIME

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
a=set()

# %%
a.add('VBZ')

# %%
a.add('NNPS')

# %%
a
# Out:
# {'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'}

# %%
tokens=nltk.word_tokenize(final_recipes[0].lower())

# %%
tagged=nltk.pos_tag(tokens)

# %%
tagged[0]
# Out:
# ('[', 'JJ')

# %%
[item for item, value in tagged if value in a]
# Out:
# ['oven',
#  'line',
#  'sheet',
#  'paper',
#  'flour',
#  'oats',
#  'sugar',
#  'parsley',
#  'bowl',
#  'combine',
#  'egg',
#  'oil',
#  'apple',
#  'carrot',
#  'mixture',
#  'egg',
#  'mixture',
#  'water',
#  'kneading',
#  'forms',
#  'dough',
#  'dough',
#  'surface',
#  'thick',
#  'shapes',
#  'roll',
#  'shapes',
#  'repeat',
#  'dough',
#  'sheet',
#  'minutes',
#  'oven',
#  'minutes',
#  'bones',
#  ']']

# %%
verbs=[]
for i in range(0,len(final_recipes)):
    tagged=nltk.pos_tag(nltk.word_tokenize(final_recipes[i].lower()))
    verbs.append([item for item, value in tagged if value in a])

# %%
len(verbs)
# Out:
# 133842

# %%
verbs[2]
# Out:
# ['mix', 'baking', 'set', 'beat', 'till', 'blended', "'cook"]

# %%
final_recipes[2].lower().strip("\'")
# Out:
# "['1.in a large bowl, mix together flour, salt, baking powder, cinnamon, nutmeg, ground cloves, ginger and flax seeds; set aside.', 'preheat waffle iron to desired temperature.', '2.in a separate bowl, beat the eggs.', 'stir in the milk, oil vanilla and honey.', '3.mix fruit in dry mixture.', '4.pour the milk mixture into the flour/fruit mixture; mix lightly till nicely blended.', '5.ladle the batter into a preheated waffle iron.', 'cook the waffles until golden and crisp.']"

# %%
nltk.pos_tag(nltk.word_tokenize(final_recipes[2].lower()))
# Out:
# [('[', 'NN'),
#  ("'", "''"),
#  ('1.in', 'CD'),
#  ('a', 'DT'),
#  ('large', 'JJ'),
#  ('bowl', 'NN'),
#  (',', ','),
#  ('mix', 'VB'),
#  ('together', 'RB'),
#  ('flour', 'NN'),
#  (',', ','),
#  ('salt', 'NN'),
#  (',', ','),
#  ('baking', 'VBG'),
#  ('powder', 'NN'),
#  (',', ','),
#  ('cinnamon', 'NN'),
#  (',', ','),
#  ('nutmeg', 'RB'),
#  (',', ','),
#  ('ground', 'NN'),
#  ('cloves', 'NNS'),
#  (',', ','),
#  ('ginger', 'NN'),
#  ('and', 'CC'),
#  ('flax', 'JJ'),
#  ('seeds', 'NNS'),
#  (';', ':'),
#  ('set', 'VBN'),
#  ('aside', 'RB'),
#  ('.', '.'),
#  ("'", "''"),
#  (',', ','),
#  ("'preheat", "''"),
#  ('waffle', 'JJ'),
#  ('iron', 'NN'),
#  ('to', 'TO'),
#  ('desired', 'JJ'),
#  ('temperature', 'NN'),
#  ('.', '.'),
#  ("'", "''"),
#  (',', ','),
#  ("'", "''"),
#  ('2.in', 'CD'),
#  ('a', 'DT'),
#  ('separate', 'JJ'),
#  ('bowl', 'NN'),
#  (',', ','),
#  ('beat', 'VBD'),
#  ('the', 'DT'),
#  ('eggs', 'NNS'),
#  ('.', '.'),
#  ("'", "''"),
#  (',', ','),
# ...

# %%
with open('recipe_verbs.txt', 'w') as fp:
    for item in verbs:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
counts=[]
for i in range (0,len(final_recipes)):
    counts.append(len(' '.join(final_recipes[i]).split()))

# %%
counts[0:20]
# Out:
# [510,
#  510,
#  405,
#  635,
#  438,
#  438,
#  558,
#  287,
#  287,
#  257,
#  587,
#  587,
#  587,
#  460,
#  460,
#  460,
#  460,
#  929,
#  584,
#  513]

# %%
len(' '.join(final_recipes[0]).split())
# Out:
# 510

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(15,8)})

# %%
sns.countplot(x=counts,color='red')
plt.xlim(0, 2000)
plt.show()

# %%
sns.histplot(x=counts,binwidth=20)
plt.xlim(0, 1000)
plt.show()

# %%
ax.set(xlim=(0, 2000))
# Out:
# [(0.0, 2000.0)]

# %%
final_recipes=[]
with open('val_recipes_final.txt', 'r') as fp:
    for line in fp:
        x = line[:-1]
        final_recipes.append(x)

# %%
final_recipes[1].count(".")
# Out:
# 9

# %%
counts=[]
for i in range (0,len(final_recipes)):
    counts.append(final_recipes[i].count("."))

# %%
sns.histplot(x=counts)
# sns.set(rc={'figure.figsize':(7,4)})
plt.xlim(0, 50)
plt.show()

# %%
a=[]
for i in range (0,len(final_recipes)):
    a.append(" ".join(final_recipes[i]))

# %%
a=["dfhjdfh"]

# %%
len(a)
# Out:
# 133842

# %%
final_recipes[2]
# Out:
# "['1.In a large bowl, mix together flour, salt, baking powder, cinnamon, nutmeg, ground cloves, ginger and Flax Seeds; set aside.', 'Preheat waffle iron to desired temperature.', '2.In a separate bowl, beat the eggs.', 'Stir in the milk, oil vanilla and honey.', '3.Mix fruit in dry mixture.', '4.Pour the milk mixture into the flour/fruit mixture; mix lightly till nicely blended.', '5.Ladle the batter into a preheated waffle iron.', 'Cook the waffles until golden and crisp.']"

# %%
total=' '.join(final_recipes[0])

# %%
final_recipes[2]+final_recipes[4]
# Out:
# '[\'1.In a large bowl, mix together flour, salt, baking powder, cinnamon, nutmeg, ground cloves, ginger and Flax Seeds; set aside.\', \'Preheat waffle iron to desired temperature.\', \'2.In a separate bowl, beat the eggs.\', \'Stir in the milk, oil vanilla and honey.\', \'3.Mix fruit in dry mixture.\', \'4.Pour the milk mixture into the flour/fruit mixture; mix lightly till nicely blended.\', \'5.Ladle the batter into a preheated waffle iron.\', \'Cook the waffles until golden and crisp.\'][\'Combine peanut butter, Crisco, brown sugar, milk, and vanilla in a large bowl.\', \'Beat at medium speed until well blended.\', \'Add egg and beat just until blended.\', \'Mix in the flour, salt, and baking soda at low speed and mix just till blended.\', \'Drop by heaping teaspoonfuls about 2" apart onto an ungreased sheet.\', \'Flatten slightly in crisscross pattern with tines of a floured fork.\', \'Bake at 375 degrees for 7-8 minutes or until set and just beginning to brown.\', \'Cool for 2 m
# ...

# %%
a=final_recipes[0]
for i in range (1,len(final_recipes)):
    a=a+final_recipes[i]

# %%
total[0:10]
# Out:
# "['Preheat "

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(a)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
# plt.close()

# %%
a=" ".join(verbs[0])
for i in range(1,len(verbs)):
    a=a+" ".join(verbs[i])

# %%
len(a)
# Out:
# 30593706

# %%
print(" ".join(nouns[0]+nouns[1]))
# Out:
# oven line sheet paper flour oats sugar parsley bowl combine egg oil apple carrot mixture egg mixture water kneading forms dough dough surface thick shapes roll shapes repeat dough sheet minutes oven minutes bones ] oven line sheet paper flour oats sugar parsley bowl combine egg oil apple carrot mixture egg mixture water kneading forms dough dough surface thick shapes roll shapes repeat dough sheet minutes oven minutes bones ]

# %%
wordcloud = WordCloud(width = 1000, height = 500,collocations=False).generate(a)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()

# %%
count=0
ingredients=[]
for i in range (0, len(layer1_j)):
    if((layer1_j[i]['id'] in ids) and count<133843):
        count=count+1
        dummy=[]
        for j in range(0,len(layer1_j[i]['ingredients'])):
            dummy.append(layer1_j[i]['ingredients'][j]['text'])
        ingredients.append(dummy)

# %%
count=0
ingredients=[]
id_ing={}
for i in range (0, len(layer1_j)):
    if((layer1_j[i]['id'] in ids) and count<133843):
        count=count+1
        # print(count)
        dummy=[]
        for j in range(0,len(layer1_j[i]['ingredients'])):
            dummy.append(layer1_j[i]['ingredients'][j]['text'])
        ingredients.append(dummy)
        id_ing[layer1_j[i]['id']]=dummy

# %%
ingredients[0]
# Out:
# ['2 1/2 cup wheat flour',
#  '1/2 cup rolled oats',
#  '1 tbsp brown sugar',
#  '2 tbsp dried parsley (optional - helps with bad breath)',
#  '1 apple - cored, peeled and grated',
#  '2 carrots - peeled and grated',
#  '1 egg - beaten',
#  '1/3 cup vegetable oil',
#  '1/4 1/2 cup of water']

# %%
len(ingredients)
# Out:
# 60422

# %%
final_ingredients=[]
for i in range(0,len(ids)):
    try:
        final_ingredients.append(id_ing[ids[i]])
    except:
        print(1)

# %%
len(final_ingredients)
# Out:
# 133842

# %%
final_ingredients[100]
# Out:
# ['6 slices bacon, diced',
#  '1 onion, diced',
#  '1 tablespoon minced garlic',
#  '1 cup chicken stock',
#  '2 (16 ounce) packages Brussels sprouts, trimmed and halved lengthwise']

# %%
with open('val_ingredients.txt', 'w') as fp:
    for item in final_ingredients:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
final_recipes[0]
# Out:
# '[\'Preheat oven to 350F and line baking sheet with parchment paper.\', \'Combine flour, oats, sugar and parsley.\', \'In separate bowl, combine egg, oil, apple and carrot.\', \'Stir flour mixture into egg mixture, slowly adding water and kneading until a dough forms.\', \'*If dough is too sticky, add more flour.\', \'Roll dough out on a lightly floured surface to 1/4" thick and cut out shapes.\', \'Knead scraps together, roll out, cut out shapes, and repeat until all dough is used.\', \'Place on baking sheet and bake for 40-45 minutes.\', \'Turn oven off and leave in oven for 20 minutes to allow bones to dry out and crisp.\']'
